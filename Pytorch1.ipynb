# %% [markdown]
# <a href="https://colab.research.google.com/github/2001pradyumnaacharya/PyTorchToutralsExpriments/blob/main/Pytorch1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/2001pradyumnaacharya/PyTorchToutralsExpriments.git
# Out:
# Cloning into 'PyTorchToutralsExpriments'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 10 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 4.54 KiB | 4.54 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
